# %%
# %load_ext rpy2.ipython
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# %%R
# install.packages("/content/gdrive/My Drive/Packages/memisc_0.99.27.3.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/prodlim_2019.11.13.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/ipred_0.9-11.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/recipes_0.1.16.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/bitops_1.0-7.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/gtools_3.9.2.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/caTools_1.18.2.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/gplots_3.1.1.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/ROCR_1.0-11.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/dplyr_1.0.7.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/proxy_0.4-26.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/e1071_1.7-8.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/randomForest_4.6-14.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/haven_2.4.3.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/ggplot2_3.3.5.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/abind_1.4-5.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/zoo_1.8-9.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/xts_0.12.1.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/TTR_0.24.2.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/quantmod_0.4.18.tar.gz", repos = NULL, type = "source")
# install.packages("/content/gdrive/My Drive/Packages/DMwR_0.4.1.tar.gz", repos = NULL, type = "source")

# %%
# %%R
# #Load packages
# library(memisc)
# library(ROCR)
# library(dplyr)
# library(e1071)
# library(randomForest)
# library(haven)
# library(ggplot2)
# library(DMwR)

# %%
# %%R
# install.packages('caret')
# library('pROC')
# library('caret')

# %%
# %%R
# data <- data.frame(read.csv("/content/gdrive/My Drive/Data/OOB.csv"))
# #TREEX <- c(25,25,25,50,50,50,75,75,75,100,100,100,125,125,125,)
# #MTRYX <- c(3,5,10,3,5,10,3,5,10,3,5,10,3,5,10)

# %%
# %%R
# dataX <- cbind(data ,T1 = factor(paste(data$Mtrys,"Mtry")))
# dataX <- cbind(dataX,T2 = factor(paste(data$Trees,"Trees")))
# dataX

# %%
# %%R
# X2 <- ggplot(data=dataX, aes(x=Trees, y=ADASYN25., group=T1)) +
#      labs(x = "Number of Tree", y = "Mean Misclassification Rate Value", title = expression(bold("Obesity Data after ADASYN with"~beta~"= 25%")))+
#           geom_line(aes(color=T1)) +
#           geom_point(aes(color=T1))+
#           theme(legend.position=c(0.9, 0.83), plot.title = element_text(face = "bold"), text = element_text(family = "Times New Roman"),
#               axis.text.x = element_text(color="black", size=12),
#               axis.text.y = element_text(color="black", size=12),
#               panel.grid.major = element_line(color  = "lightgray", size = 0.1),
#               panel.background = element_rect(fill = "white", color = "black", size = 2)) +
#           scale_y_continuous(limits = c(0,0.5), labels = scales::percent) + scale_colour_discrete("Mtry Types") +
#           scale_x_continuous(breaks = c(25,50,75,100,125,150,175)) + geom_vline(xintercept=50, linetype="dashed", color = "black")
#
# X3 <- ggplot(data=dataX, aes(x=Trees, y=ADASYN50., group=T1)) +
#      labs(x = "Number of Tree", y = "Mean Misclassification Rate Value", title = expression(bold("Obesity Data after ADASYN with"~beta~"= 50%")))+
#           geom_line(aes(color=T1)) +
#           geom_point(aes(color=T1))+
#           theme(legend.position=c(0.9, 0.83), plot.title = element_text(face = "bold"), text = element_text(family = "Times New Roman"),
#               axis.text.x = element_text(color="black", size=12),
#               axis.text.y = element_text(color="black", size=12),
#               panel.grid.major = element_line(color  = "lightgray", size = 0.1),
#               panel.background = element_rect(fill = "white", color = "black", size = 2)) +
#           scale_y_continuous(limits = c(0,0.5), labels = scales::percent) + scale_colour_discrete("Mtry Types") +
#           scale_x_continuous(breaks = c(25,50,75,100,125,150,175)) + geom_vline(xintercept=50, linetype="dashed", color = "black")
#
# X4 <- ggplot(data=dataX, aes(x=Trees, y=ADASYN75., group=T1)) +
#      labs(x = "Number of Tree", y = "Mean Misclassification Rate Value", title = expression(bold("Obesity Data after ADASYN with"~beta~"= 75%")))+
#           geom_line(aes(color=T1)) +
#           geom_point(aes(color=T1))+
#           theme(legend.position=c(0.9, 0.83), plot.title = element_text(face = "bold"), text = element_text(family = "Times New Roman"),
#               axis.text.x = element_text(color="black", size=12),
#               axis.text.y = element_text(color="black", size=12),
#               panel.grid.major = element_line(color  = "lightgray", size = 0.1),
#               panel.background = element_rect(fill = "white", color = "black", size = 2)) +
#           scale_y_continuous(limits = c(0,0.5), labels = scales::percent) + scale_colour_discrete("Mtry Types") +
#           scale_x_continuous(breaks = c(25,50,75,100,125,150,175)) + geom_vline(xintercept=75, linetype="dashed", color = "black")
#
# X5 <- ggplot(data=dataX, aes(x=Trees, y=ADASYN100., group=T1)) +
#      labs(x = "Number of Tree", y = "Mean Misclassification Rate Value", title = expression(bold("Obesity Data after ADASYN with"~beta~"= 100%")))+
#           geom_line(aes(color=T1)) +
#           geom_point(aes(color=T1))+
#           theme(legend.position=c(0.9, 0.83), plot.title = element_text(face = "bold"), text = element_text(family = "Times New Roman"),
#               axis.text.x = element_text(color="black", size=12),
#               axis.text.y = element_text(color="black", size=12),
#               panel.grid.major = element_line(color  = "lightgray", size = 0.1),
#               panel.background = element_rect(fill = "white", color = "black", size = 2)) +
#           scale_y_continuous(limits = c(0,0.5), labels = scales::percent) + scale_colour_discrete("Mtry Types") +
#           scale_x_continuous(breaks = c(25,50,75,100,125,150,175)) + geom_vline(xintercept=75, linetype="dashed", color = "black")

# %%
# %%R
# Y2 <- ggplot(data=dataX, aes(x=Mtrys, y=ADASYN25., group=T2)) +
#      labs(x = "Number of Mtry", y = "Mean Misclassification Rate Value", title = expression(bold("Obesity Data after ADASYN with"~beta~"= 25%")))+
#           geom_line(aes(color=T2))+
#           geom_point(aes(color=T2))+
#           theme(legend.position=c(0.89, 0.79), plot.title = element_text(face = "bold"), text = element_text(family = "Times New Roman"),
#               axis.text.x = element_text(color="black", size=12),
#               axis.text.y = element_text(color="black", size=12),
#               panel.grid.major = element_line(color  = "lightgray", size = 0.1),
#               panel.background = element_rect(fill = "white", color = "black", size = 2)) +
#           scale_y_continuous(limits = c(0,0.5), labels = scales::percent) + scale_colour_discrete("Tree Types") +
#           scale_x_continuous(breaks = c(1,3,5,7,9)) + geom_vline(xintercept=5, linetype="dashed", color = "black")
#
# Y3 <- ggplot(data=dataX, aes(x=Mtrys, y=ADASYN50., group=T2)) +
#      labs(x = "Number of Mtry", y = "Mean Misclassification Rate Value", title = expression(bold("Obesity Data after ADASYN with"~beta~"= 50%")))+
#           geom_line(aes(color=T2))+
#           geom_point(aes(color=T2))+
#           theme(legend.position=c(0.89, 0.79), plot.title = element_text(face = "bold"), text = element_text(family = "Times New Roman"),
#               axis.text.x = element_text(color="black", size=12),
#               axis.text.y = element_text(color="black", size=12),
#               panel.grid.major = element_line(color  = "lightgray", size = 0.1),
#               panel.background = element_rect(fill = "white", color = "black", size = 2)) +
#           scale_y_continuous(limits = c(0,0.5), labels = scales::percent) + scale_colour_discrete("Tree Types") +
#           scale_x_continuous(breaks = c(1,3,5,7,9)) + geom_vline(xintercept=5, linetype="dashed", color = "black")
#
# Y4 <- ggplot(data=dataX, aes(x=Mtrys, y=ADASYN75., group=T2)) +
#      labs(x = "Number of Mtry", y = "Mean Misclassification Rate Value", title = expression(bold("Obesity Data after ADASYN with"~beta~"= 75%")))+
#           geom_line(aes(color=T2))+
#           geom_point(aes(color=T2))+
#           theme(legend.position=c(0.89, 0.79), plot.title = element_text(face = "bold"), text = element_text(family = "Times New Roman"),
#               axis.text.x = element_text(color="black", size=12),
#               axis.text.y = element_text(color="black", size=12),
#               panel.grid.major = element_line(color  = "lightgray", size = 0.1),
#               panel.background = element_rect(fill = "white", color = "black", size = 2)) +
#           scale_y_continuous(limits = c(0,0.5), labels = scales::percent) + scale_colour_discrete("Tree Types") +
#           scale_x_continuous(breaks = c(1,3,5,7,9)) + geom_vline(xintercept=5, linetype="dashed", color = "black")
#
# Y5 <- ggplot(data=dataX, aes(x=Mtrys, y=ADASYN100., group=T2)) +
#      labs(x = "Number of Mtry", y = "Mean Misclassification Rate Value", title = expression(bold("Obesity Data after ADASYN with"~beta~"= 100%")))+
#           geom_line(aes(color=T2))+
#           geom_point(aes(color=T2))+
#           theme(legend.position=c(0.89, 0.79), plot.title = element_text(face = "bold"), text = element_text(family = "Times New Roman"),
#               axis.text.x = element_text(color="black", size=12),
#               axis.text.y = element_text(color="black", size=12),
#               panel.grid.major = element_line(color  = "lightgray", size = 0.1),
#               panel.background = element_rect(fill = "white", color = "black", size = 2)) +
#           scale_y_continuous(limits = c(0,0.5), labels = scales::percent) + scale_colour_discrete("Tree Types") +
#           scale_x_continuous(breaks = c(1,3,5,7,9)) + geom_vline(xintercept=5, linetype="dashed", color = "black")

# %%
# %%R
# install.packages('gridExtra')
# library('gridExtra')
# G1 <- grid.arrange(Y2, Y3, Y4, Y5, nrow = 2)
# G2 <- grid.arrange(X2, X3, X4, X5, nrow = 2)
#
# ggsave(plot = G1, filename = paste("/content/gdrive/My Drive/Result/By Mtry.jpg"), width = 14, height = 12)
# ggsave(plot = G2, filename = paste("/content/gdrive/My Drive/Result/By Tree.jpg"), width = 14, height = 12)

# %%
# %%R
# Y1 <- ggplot(data=dataX, aes(x=Mtrys, y=REAL, group=T2)) +
#      labs(x = "Number of Mtry", y = "Mean Misclassification Rate Value", title = expression(bold("Obesity Data before ADASYN:")~"Grouped by Tree"))+
#           geom_line(aes(color=T2))+
#           geom_point(aes(color=T2))+
#           theme(legend.position=c(0.89, 0.79), plot.title = element_text(face = "bold"), text = element_text(family = "Times New Roman"),
#               axis.text.x = element_text(color="black", size=12),
#               axis.text.y = element_text(color="black", size=12),
#               panel.grid.major = element_line(color  = "lightgray", size = 0.1),
#               panel.background = element_rect(fill = "white", color = "black", size = 2)) +
#           scale_y_continuous(limits = c(0,0.5), labels = scales::percent) + scale_colour_discrete("Tree Types") +
#           scale_x_continuous(breaks = c(1,3,5,7,9)) + geom_vline(xintercept=3, linetype="dashed", color = "black")
#
# X1 <- ggplot(data=dataX, aes(x=Trees, y=REAL, group=T1)) +
#      labs(x = "Number of Tree", y = "Mean Misclassification Rate Value", title = expression(bold("Obesity Data before ADASYN:")~"Grouped by Mtry"))+
#           geom_line(aes(color=T1)) +
#           geom_point(aes(color=T1))+
#           theme(legend.position=c(0.9, 0.83), plot.title = element_text(face = "bold"), text = element_text(family = "Times New Roman"),
#               axis.text.x = element_text(color="black", size=12),
#               axis.text.y = element_text(color="black", size=12),
#               panel.grid.major = element_line(color  = "lightgray", size = 0.1),
#               panel.background = element_rect(fill = "white", color = "black", size = 2)) +
#           scale_y_continuous(limits = c(0,0.5), labels = scales::percent) + scale_colour_discrete("Mtry Types") +
#           scale_x_continuous(breaks = c(25,50,75,100,125,150,175)) + geom_vline(xintercept=50, linetype="dashed", color = "black")
# G3 <- grid.arrange(Y1, X1, nrow = 1)
# ggsave(plot = G3, filename = paste("/content/gdrive/My Drive/Result/By Start.jpg"), width = 14, height = 6)

# %%
# %%R
# Train <- read.csv('/content/gdrive/My Drive/Data/3.25 TRAIN DATA.csv')
# print(dim(filter(Train, X12%in%"Obesitas")))
# Train <- read.csv('/content/gdrive/My Drive/Data/4.50 TRAIN DATA.csv')
# print(dim(filter(Train, X12%in%"Obesitas")))
# Train <- read.csv('/content/gdrive/My Drive/Data/5.75 TRAIN DATA.csv')
# print(dim(filter(Train, X12%in%"Obesitas")))
# Train <- read.csv('/content/gdrive/My Drive/Data/6.100 TRAIN DATA.csv')
# print(dim(filter(Train, X12%in%"Obesitas")))

# %%
# %%R
# Train <- read.csv('/content/gdrive/My Drive/Data/2.OR TRAIN DATA.csv')
# print(dim(Train))
# print(dim(filter(Train, X12%in%"Obesitas")))
# print(dim(filter(Train, X12%in%"Normal")))
#
# Train <- read.csv('/content/gdrive/My Drive/Data/1.TEST DATA.csv')
# print(dim(Train))
# print(dim(filter(Train, X12%in%"Obesitas")))
# print(dim(filter(Train, X12%in%"Normal")))
